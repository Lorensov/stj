# %%
import os, json
import pandas as pd

path_to_json = './data/raw/2016/'
json_files = [pos_json for pos_json in os.listdir(path_to_json) if pos_json.endswith('.json')]
#print(json_files)  # for me this prints ['foo.json']

# %%
import pandas as pd

# %%
json_file = ''
df_raw = pd.read_json('./data/raw/2016/276_2016.json')
#df_raw

# %%
df_raw

# %%
df_raw['description']

# %%
df_raw[df_raw['description'].str.contains("Lucian", na = False)]

# %%
df_raw.columns
# Out:
# Index(['autoridade', 'data', 'description', 'facet-autoridade',
#        'facet-localidade', 'facet-tipoDocumento', 'identifier', 'localidade',
#        'tipoDocumento', 'title', 'type', 'url', 'urn'],
#       dtype='object')

# %%
for col in df_raw.columns:
    print(col)

# %%
df_raw.describe()

# %%
df_raw.info

# %%
pd.set_option('display.max_colwidth', -1)

# %%
df_raw['description']

# %%
import os, json
import pandas as pd

# this finds our json files
path_to_json = 'data/raw/2016/'
json_files = [pos_json for pos_json in os.listdir(path_to_json) if pos_json.endswith('.json')]

df_created = pd.DataFrame(columns=['autoridade', 'data', 'description', 'facet-autoridade',
       'facet-localidade', 'facet-tipoDocumento', 'identifier', 'localidade',
       'tipoDocumento', 'title', 'type', 'url', 'urn'])

# here I define my pandas Dataframe with
for index, js in enumerate(json_files):
    with open(os.path.join(path_to_json, js)) as json_file:
        json_text = json.load(json_file)
        
        #country = json_text['features'][0]['properties']['country']
        #city = json_text['features'][0]['properties']['name']
        #lonlat = json_text['features'][0]['geometry']['coordinates']
        # here I push a list of data into a pandas DataFrame at row given by 'index'
        #
        
        #jsons_data.loc[index] = [country, city, lonlat]
        
        
print(json_text)
# Out:
# [{'tipoDocumento': 'Acórdão', 'facet-tipoDocumento': 'Jurisprudência::Acórdão', 'data': '2016-11-28', 'urn': 'urn:lex:br;justica.trabalho;regiao.1:tribunal.regional.trabalho;turma.4:acordao:2016-11-28;00107976320145010431', 'url': 'https://www.lexml.gov.br/urn/urn:lex:br;justica.trabalho;regiao.1:tribunal.regional.trabalho;turma.4:acordao:2016-11-28;00107976320145010431', 'localidade': '1a Região - Rio de Janeiro', 'facet-localidade': 'Brasil::Justiça do Trabalho::1a Região - Rio de Janeiro', 'autoridade': 'Tribunal Regional do Trabalho. 4a Turma', 'facet-autoridade': 'Federal::Judiciário::Tribunal Regional do Trabalho::4a Turma', 'title': 'ACÓRDÃO TRT 1a  / 4a Turma / 0010797-63.2014.5.01.0431 - DOERJ 28-11-2016', 'description': 'EMBARGOS DE DECLARAÇÃO - Inexistindo contradição, omissão ou obscuridade, tampouco erro material, impossível acolher os embargos de declaração.', 'type': 'html', 'identifier': '012726462'}, {'tipoDocumento': 'Acórdão', 'facet-tipoDocumento': 'Jurisprudência::Acórdão', 'data': '2016-11-24', 'urn': 'urn:lex:br;justica.trabalho;regiao.1:tribunal.regional.trabalho;secao.dissidios.individuais.1:acordao:2016-11-24;01001481120165010000', 'url': 'https://www.lexml.gov.br/urn/urn:lex:br;justica.trabalho;regiao.1:tribunal.regional.trabalho;secao.dissidios.individuais.1:acordao:2016-11-24;01001481120165010000', 'localidade': '1a Região - Rio de Janeiro', 'facet-localidade': 'Brasil::Justiça do Trabalho::1a Região - Rio de Janeiro', 'autoridade': 'Tribunal Regional do Trabalho. 1a Seção de Dissídios Individuais', 'facet-autoridade': 'Federal::Judiciário::Tribunal Regional do Trabalho::1a Seção de Dissídios Individuais', 'title': 'ACÓRDÃO TRT 1a  / SEDI-1 / 0100148-11.2016.5.01.0000 - DOERJ 24-11-2016', 'description': None, 'type': 'html', 'identifier': '012726463'}, {'tipoDocumento': 'Acórdão', 'facet-tipoDocumento': 'Jurisprudência::Acórdão', 'data': '2016-11-24', 'urn': 'urn:lex:br;justica.trabalho;regiao.1:tribunal.regional.trabalho;secao.dissidios.individuais.1:acordao:2016-11-24;01006106520165010000', 'url': 'https://www.lexml.gov.br/urn/urn:lex:br;justica.trabalho;regiao.1:tribunal.regional.trabalho;secao.dissidios.individuais.1:acordao:2016-11-24;01006106520165010000', 'localidade': '1a Região - Rio de Janeiro', 'facet-localidade': 'Brasil::Justiça do Trabalho::1a Região - Rio de Janeiro', 'autoridade': 'Tribunal Regional do Trabalho. 1a Seção de Dissídios Individuais', 'facet-autoridade': 'Federal::Judiciário::Tribunal Regional do Trabalho::1a Seção de Dissídios Individuais', 'title': 'ACÓRDÃO TRT 1a  / SEDI-1 / 0100610-65.2016.5.01.0000 - DOERJ 24-11-2016', 'description': 'AGRAVO REGIMENTAL. AÇÃO RESCISÓRIA. LIMINAR. EFEITO SUSPENSIVO. EXCEPCIONALIDADE. A concessão de medida liminar em Ação Rescisória que pretende conferir efeito suspensivo a execução em andamento, só se viabiliza em circunstâncias restritas, em situações excepcionais de êxito da pretensão, o que não se verifica no caso. Agravo Regimental interposto por Playvender Distribuidora de Higiene e Limpeza Ltda conhecido e não provido.', 'type': 'html', 'identifier': '012726464'}, {'tipoDocumento': 'Acórdão', 'facet-tipoDocumento': 'Jurisprudência::Acórdão', 'data': '2016-11-24', 'urn': 'urn:lex:br;justica.trabalho;regiao.1:tribunal.regional.trabalho;turma.3:acordao:2016-11-24;00109498620155010040', 'url': 'https://www.lexml.gov.br/urn/urn:lex:br;justica.trabalho;regiao.1:tribunal.regional.trabalho;turma.3:acordao:2016-11-24;00109498620155010040', 'localidade': '1a Região - Rio de Janeiro', 'facet-localidade': 'Brasil::Justiça do Trabalho::1a Região - Rio de Janeiro', 'autoridade': 'Tribunal Regional do Trabalho. 3a Turma', 'facet-autoridade': 'Federal::Judiciário::Tribunal Regional do Trabalho::3a Turma', 'title': 'ACÓRDÃO TRT 1a  / 3a Turma / 0010949-86.2015.5.01.0040 - DOERJ 24-11-2016', 'description': 'INDENIZAÇÃO POR DANOS MORAIS. LIMBO JURÍDICO. CABIMENTO. ...

# %%
df_raw = pd.read_json(json_text, lines=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-03c8828c8fa7> in <module>()
# ----> 1 df_raw = pd.read_json(json_text, lines=True)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/json/json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     406     compression = _infer_compression(path_or_buf, compression)
#     407     filepath_or_buffer, _, compression, should_close = get_filepath_or_buffer(
# --> 408         path_or_buf, encoding=encoding, compression=compression,
#     409     )
#     410
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/common.py in get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode)
#     216     if not is_file_like(filepath_or_buffer):
#     217         msg = "Invalid file path or buffer object type: {_type}"
# --> 218         raise ValueError(msg.format(_type=type(filepath_or_buffer)))
#     219
#     220     return filepath_or_buffer, None, compression, False
#
# ValueError: Invalid file path or buffer object type: <class 'list'>
